# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
plt.figure()
plt.title('SIMPLE-LINEAR-REGRESSION')
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,noise=15,random_state=3)
plt.scatter(x,y,color='red',marker='o',s=30)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
knn=KNeighborsRegressor(n_neighbors=55)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
knn.fit(x_train,y_train)
predict=knn.predict(x_test)
print(knn.score(x_test,y_test),predict,sep='\n')
# Out:
# 0.3450213550506873
# [  1.08875643   9.92486706 -18.07271491  13.76389399 -18.07271491
#  -18.07271491   1.08875643 -16.44484246 -18.07271491 -18.07271491
#  -14.96637846   1.08875643 -18.07271491 -18.07271491   9.92486706
#   13.76389399  -3.11306718 -13.70735596  -5.63683787 -18.07271491]

# %%
plt.scatter(x_train,y_train,color='red' )
plt.scatter(x_test,predict,marker='^',s=90)

# %%
import numpy as np
x_new=np.linspace(-3,2,100).reshape(100,1)
predict_new=knn.predict(x_new)
plt.plot(x_new,predict_new,color='blue')
plt.scatter(x_train,y_train,color='red' )
plt.scatter(x_test,predict,marker='^',s=90)
